# %%
# Cell 1: Define the Universal Anatomy Prompt Template
universal_template = """
You are a medical anatomy expert. Create a comprehensive, high-yield, and exam-oriented answer for the following question. Use the following response structure:

1. **Introduction** – Brief overview and relevance of the structure/system.
2. **Anatomical Details**:
   - Origin / Root Value (if applicable)
   - Course or Pathway
   - Relations (describe and use a table if suitable)
   - Branches / Divisions / Parts
   - Termination / Insertion / Drainage / Supply (as applicable)
3. **Functional Significance** – Role in physiology or clinical anatomy.
4. **Applied/Clinical Anatomy** – Common clinical correlations, nerve blocks, injuries, imaging relevance, etc.
5. **Visual Aids**:
   - Use bullet points for clarity.
   - Insert summary tables where useful.
   - Describe or generate diagrams (ASCII or label descriptions).
6. **Conclusion** – One-line summary or importance.

**Question:**  
{Insert Anatomy Question Here}

Ensure the content is structured, concise, and visually enhanced for postgraduate medical students. Avoid unnecessary elaboration but retain all high-yield anatomical and clinical points.
"""

# %%
# Cell 2: Insert Your Anatomy Question Here
anatomy_question = "Describe the origin, course, relations, and branches of the facial nerve."

# Generate the final prompt for the language model
final_prompt = universal_template.replace("{Insert Anatomy Question Here}", anatomy_question)

# Display the prompt (or send to model)
print(final_prompt)

# %%
# Cell 3: Call to the Language Model (replace with actual call)
# Example: response = ask_gpt(final_prompt)
# display(Markdown(response))
